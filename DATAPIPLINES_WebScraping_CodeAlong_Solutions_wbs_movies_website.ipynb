# %% [markdown]
# <a href="https://colab.research.google.com/github/Loanisa/oceanarium/blob/main/WebScraping_CodeAlong_Solutions_wbs_movies_website.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intro to web scraping

# %% [markdown]
# The first step of web scraping is to identify a website and download the html code from it.
#
# Real html from websites tends to be long and a bit too chaotic for a total beginner. Here we will start with a dummy html document and learn the basics of extracting info with beautifulsoup.

# %%
html_doc = """
<!DOCTYPE html>
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
</html>
"""

# %%
html_doc
# Out:
# '\n<!DOCTYPE html>\n<html><head><title>The Dormouse\'s story</title></head>\n<body>\n<p class="title"><b>The Dormouse\'s story</b></p>\n\n<p class="story">Once upon a time there were three little sisters; and their names were\n<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,\n<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and\n<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;\nand they lived at the bottom of a well.</p>\n\n<p class="story">...</p>\n</html>\n'

# %%
# !pip install --upgrade beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.0/143.0 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.4.1)
# Installing collected packages: beautifulsoup4
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.11.2
#     Uninstalling beautifulsoup4-4.11.2:
#       Successfully uninstalled beautifulsoup4-4.11.2
# Successfully installed beautifulsoup4-4.12.2

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# #### "creating the soup"

# %%
# parse the element
soup = BeautifulSoup(html_doc, 'html.parser')

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of
# <!DOCTYPE html>
#
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body></html>
# >

# %% [markdown]
# #### accessing single elements

# %%
soup.title
# Out:
# <title>The Dormouse's story</title>

# %%
soup.title.string
# Out:
# "The Dormouse's story"

# %%
soup.title.parent.name
# Out:
# 'head'

# %%
soup.body
# Out:
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body>

# %%
# this method only retrieves the first element of the specified tag
soup.p
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %% [markdown]
# #### finding all elements of a tag with find_all()

# %%
p_tags = soup.find_all("p")

# %%
p_tags
# Out:
# [<p class="title"><b>The Dormouse's story</b></p>,
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  <p class="story">...</p>]

# %%
for p in p_tags:
    print(p.get_text())
# Out:
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...

# %% [markdown]
# #### Using css selectors
#
# https://htmlcheatsheet.com/css/

# %%
# select all elements with class="title"
soup.select(".title")
# Out:
# [<p class="title"><b>The Dormouse's story</b></p>]

# %%
# select all elements with class="sister"
soup.select(".sister")
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
# select "all" elements with the id="link2"
soup.select("#link2")
# Out:
# [<a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>]

# %% [markdown]
# We can combine the `select()` method with other bs4 methods, such as `get_text()`.
#
# `get_text()`, however, can only be applied to single elements, while `select()` might return multiple elements. It's common to iterate through the output of `select()`

# %%
print(soup.select("p.story")[0].get_text())
# Out:
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.

# %%
for p in soup.select("p.story"):
    print(p.get_text())
# Out:
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...

# %% [markdown]
# ### Your turn:
#
# Write code to print the following contents (not including the html tags, only human-readable text):
#
# 1. All the "fun facts".
#
# 2. The names of all the places.
#
# 3. The content (name and fact) of all the cities (only cities, not countries!)
#
# 4. The names (not facts!) of all the cities (not countries!)

# %%
geography = """
<!DOCTYPE html>
<html>
<head> Geography</head>
<body>

<div class="city">
  <h2>London</h2>
  <p>London is the most popular tourist destination in the world.</p>
</div>

<div class="city">
  <h2>Paris</h2>
  <p>Paris was originally a Roman City called Lutetia.</p>
</div>

<div class="country">
  <h2>Spain</h2>
  <p>Spain produces 43,8% of all the world's Olive Oil.</p>
</div>

</body>
</html>
"""

# %%
# Create the "soup"

# %%
# 1. All the "fun facts"

# %%
# 2. The names of all the places.

# %%
# 3. All the content (name and fact) of all the cities (only cities, not countries!)

# %%
# 4. The names (not facts!) of all the cities (not countries!)

# %% [markdown]
# ## Use case: imdb top charts
#
# Let's go to https://wbscodingschool.github.io/wbs-movies-website/, where we'll see the top 250 movies according to user ratings.
#
# Notice how each movie has the following elements:
#
# - Title
#
# - Release Year
#
# - Rating
#
# Our objective is going to be to scrape this information and store it in a pandas dataframe.

# %%
# 1. import libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# 2. find url and store it in a variable
url = "https://wbscodingschool.github.io/wbs-movies-website/"

# %% [markdown]
# The `robots.txt` file is like a guide for web robots (or "bots") visiting a website. It tells these bots which parts of the website they are allowed to visit and which parts they should avoid. However, it's more like a suggestion rather than a rule, so not all bots will follow it. It's mainly used to manage how bots interact with a website but should not be used as a way to secure sensitive parts of a site.
#
# A step by step guide to check any `robots.txt` website would be:
#
# - Step 1: Open a web browser of your choice (Google Chrome, Firefox, Safari, etc.).
#
# - Step 2: In the URL bar, type the website's address, followed by "/robots.txt". For example, if you wanted to see the robots.txt file for Google, you would type in "https://www.google.com/robots.txt".
#
# - Step 3: Press enter to navigate to that address.
#
# **How to understand the robots.txt?**
#
# Let's imagine we have the following robots.txt file:
#
# ```
# User-agent: *
# Disallow: /private/
# Allow: /public/
# ```
#
# * The "User-agent: *" part means that the following rules apply to all web robots.
# * The "Disallow: /private/" part tells robots not to access anything in the "/private/" directory of the website.
# * The "Allow: /public/" part tells robots that they are allowed to access the "/public/" directory.
#
# In the absence of "Allow" or "Disallow" directives, the default is to allow access. So, if a robots.txt file only specifies "Disallow" directives, robots can assume they're allowed to access any part of the site not explicitly disallowed.
#
# Let's check the robots from the website we will get the info https://wbscodingschool.github.io/wbs-movies-website/robots.txt .

# %%
# now, we know we can access with our code (robot) to the website safely.
# Let's go to it :)
# 3. download html with a get request
response = requests.get(url)
response.status_code # 200 status code means OK!
# Out:
# 200

# %%
# 4.1. parse html (create the 'soup')
soup = BeautifulSoup(response.content, "html.parser")
# 4.2. check that the html code looks like it should
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <title>Top Rated Movies</title>
# <link href="styles.css" rel="stylesheet"/>
# </head>
# <main>
# <header class="headerTitle">
# <h1 class="title">Top 100 Movies from all time</h1>
# <p class="description">Welcome to the Top Rated Movies List!</p>
# </header>
# <table class="moviesTable">
# <tr class="tableHeaders">
# <th>Rank &amp; Title</th>
# <th>WBS Rating</th>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">1. The Shawshank Redemption (1994)</td>
# <td class="movieRating">9.2</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">2. The Godfather (1972)</td>
# <td class="movieRating">9.2</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">3. The Dark Knight (2008)</td>
# <td class="movieRating">9.0</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">4. The Godfather Part II (1974)</td>
# <td class="movieRating">9.0</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">5. 12 Angry Men (1957)</td>
# <td class="movieRating">9.0</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">6. Schindler's List (1993)</td>
# <td class="movieRating">8.9</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">
#           7. The Lord of the Rings: The Return of the King (2003)
#         </td>
# <td class="movieRating">8.9</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">8. Pulp Fiction (1994)</td>
# <td class="movieRating">8.8</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">
#           9. The Lord of the Rings: The Fellowship of the Ring (2001)
#         </td>
# <td class="movieRating">8.8</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">10. The Good, the Bad and the Ugly (1966)</td>
# <td class="movieRating">8.8</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">11. Forrest Gump (1994)</td>
# <td class="movieRating">8.8</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">
#           12. Spider-Man: Across the Spider-Verse (2023)
#         </td>
# <td class="movieRating">8.8</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">13. Fight Club (1999)</td>
# <td class="movieRating">8.7</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">
#           14. The Lord of the Rings: The Two Towers (2002)
#         </td>
# <td class="movieRating">8.7</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">15. Inception (2010)</td>
# <td class="movieRating">8.7</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">
#           16. Star Wars: Episode V - The Empire Strikes Back (1980)
#         </td>
# <td class="movieRating">8.7</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">17. The Matrix (1999)</td>
# <td class="movieRating">8.7</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">18. GoodFellas (1990)</td>
# <td class="movieRating">8.7</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">19. One Flew Over the Cuckoo's Nest (1975)</td>
# <td class="movieRating">8.6</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">20. Seven (1995)</td>
# <td class="movieRating">8.6</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">21. It's a Wonderful Life (1946)</td>
# <td class="movieRating">8.6</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">22. Seven Samurai (1954)</td>
# <td class="movieRating">8.6</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">23. The Silence of the Lambs (1991)</td>
# <td class="movieRating">8.6</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">24. Saving Private Ryan (1998)</td>
# <td class="movieRating">8.6</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">25. City of God (2002)</td>
# <td class="movieRating">8.6</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">26. Interstellar (2014)</td>
# <td class="movieRating">8.6</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">27. Life Is Beautiful (1997)</td>
# <td class="movieRating">8.6</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">28. The Green Mile (1999)</td>
# <td class="movieRating">8.6</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">
#           29. Star Wars: Episode IV - A New Hope (1977)
#         </td>
# <td class="movieRating">8.5</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">30. Terminator 2: Judgment Day (1991)</td>
# <td class="movieRating">8.5</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">31. Back to the Future (1985)</td>
# <td class="movieRating">8.5</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">32. Spirited Away (2001)</td>
# <td class="movieRating">8.5</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">33. The Pianist (2002)</td>
# <td class="movieRating">8.5</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">34. Psycho (1960)</td>
# <td class="movieRating">8.5</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">35. Parasite (2019)</td>
# <td class="movieRating">8.5</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">36. Leon (1994)</td>
# <td class="movieRating">8.5</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">37. The Lion King (1994)</td>
# <td class="movieRating">8.5</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">38. Gladiator (2000)</td>
# <td class="movieRating">8.5</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">39. American History X (1998)</td>
# <td class="movieRating">8.5</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">40. The Departed (2006)</td>
# <td class="movieRating">8.5</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">41. Whiplash (2014)</td>
# <td class="movieRating">8.5</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">42. The Prestige (2006)</td>
# <td class="movieRating">8.5</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">43. The Usual Suspects (1995)</td>
# <td class="movieRating">8.5</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">44. Casablanca (1942)</td>
# <td class="movieRating">8.5</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">45. Grave of the Fireflies (1988)</td>
# <td class="movieRating">8.5</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">46. Harakiri (1962)</td>
# <td class="movieRating">8.5</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">47. Untouchable (2011)</td>
# <td class="movieRating">8.5</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">48. Modern Times (1936)</td>
# <td class="movieRating">8.4</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">49. Once Upon a Time in the West (1968)</td>
# <td class="movieRating">8.4</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">50. Cinema Paradiso (1988)</td>
# <td class="movieRating">8.4</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">51. Rear Window (1954)</td>
# <td class="movieRating">8.4</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">52. Alien (1979)</td>
# <td class="movieRating">8.4</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">53. City Lights (1931)</td>
# <td class="movieRating">8.4</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">54. Apocalypse Now (1979)</td>
# <td class="movieRating">8.4</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">55. Memento (2000)</td>
# <td class="movieRating">8.4</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">56. Django Unchained (2012)</td>
# <td class="movieRating">8.4</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">57. Raiders of the Lost Ark (1981)</td>
# <td class="movieRating">8.4</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">58. WALL·E (2008)</td>
# <td class="movieRating">8.4</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">59. The Lives of Others (2006)</td>
# <td class="movieRating">8.4</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">60. Sunset Blvd. (1950)</td>
# <td class="movieRating">8.4</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">61. Paths of Glory (1957)</td>
# <td class="movieRating">8.4</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">62. Avengers: Infinity War (2018)</td>
# <td class="movieRating">8.4</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">63. The Shining (1980)</td>
# <td class="movieRating">8.4</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">64. The Great Dictator (1940)</td>
# <td class="movieRating">8.4</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">65. Witness for the Prosecution (1957)</td>
# <td class="movieRating">8.4</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">66. Spider-Man: Into the Spider-Verse (2018)</td>
# <td class="movieRating">8.4</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">67. Aliens (1986)</td>
# <td class="movieRating">8.3</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">68. American Beauty (1999)</td>
# <td class="movieRating">8.3</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">69. The Dark Knight Rises (2012)</td>
# <td class="movieRating">8.3</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">70. Galaxy's Echo (2023)</td>
# <td class="movieRating">8.3</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">71. Unraveled Mystery (2023)</td>
# <td class="movieRating">8.2</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">72. Oceans of Time (2023)</td>
# <td class="movieRating">8.2</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">73. Last Breath (2023)</td>
# <td class="movieRating">8.2</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">74. Dimensions Apart (2023)</td>
# <td class="movieRating">8.2</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">75. Chasing Infinity (2023)</td>
# <td class="movieRating">8.1</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">76. The Lost Kingdom (2023)</td>
# <td class="movieRating">8.1</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">77. Golden Eclipse (2023)</td>
# <td class="movieRating">8.1</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">78. Heart of The Ocean (2023)</td>
# <td class="movieRating">8.1</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">79. Cursed Shadows (2023)</td>
# <td class="movieRating">8.0</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">80. Memory of A Ghost (2023)</td>
# <td class="movieRating">8.0</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">81. Mystic Sunrise (2023)</td>
# <td class="movieRating">8.0</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">82. Whisper of the Wind (2023)</td>
# <td class="movieRating">8.0</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">83. Frozen Heartbeat (2023)</td>
# <td class="movieRating">7.9</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">84. The Last Horizon (2023)</td>
# <td class="movieRating">7.9</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">85. City of Dreams (2023)</td>
# <td class="movieRating">7.9</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">86. Veil of Destiny (2023)</td>
# <td class="movieRating">7.9</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">87. Phoenix Rise (2023)</td>
# <td class="movieRating">7.8</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">88. Secrets in The Sand (2023)</td>
# <td class="movieRating">7.8</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">89. Riddle of The Sphinx (2023)</td>
# <td class="movieRating">7.8</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">90. Solar Storm (2023)</td>
# <td class="movieRating">7.8</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">91. Quantum Conundrum (2023)</td>
# <td class="movieRating">7.7</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">92. Labyrinth of Illusions (2023)</td>
# <td class="movieRating">7.7</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">93. Stars and Shadows (2023)</td>
# <td class="movieRating">7.7</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">94. Eternal Flame (2023)</td>
# <td class="movieRating">7.7</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">95. The Jade Serpent (2023)</td>
# <td class="movieRating">7.6</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">96. Moon's Reflection (2023)</td>
# <td class="movieRating">7.6</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">97. Dance of The Silver Phoenix (2023)</td>
# <td class="movieRating">7.6</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">98. Crystal Visions (2023)</td>
# <td class="movieRating">7.6</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">99. Silver Mirror (2023)</td>
# <td class="movieRating">7.5</td>
# </tr>
# <tr class="movieInfo">
# <td class="movieTitle">100. The Forgotten Realm (2023)</td>
# <td class="movieRating">7.5</td>
# </tr>
# </table>
# <script src="script.js"></script>
# </main>
# </html>

# %%
soup.select("tr.movieInfo") # all the info about all the movies
# Out:
# [<tr class="movieInfo">
#  <td class="movieTitle">1. The Shawshank Redemption (1994)</td>
#  <td class="movieRating">9.2</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">2. The Godfather (1972)</td>
#  <td class="movieRating">9.2</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">3. The Dark Knight (2008)</td>
#  <td class="movieRating">9.0</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">4. The Godfather Part II (1974)</td>
#  <td class="movieRating">9.0</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">5. 12 Angry Men (1957)</td>
#  <td class="movieRating">9.0</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">6. Schindler's List (1993)</td>
#  <td class="movieRating">8.9</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">
#            7. The Lord of the Rings: The Return of the King (2003)
#          </td>
#  <td class="movieRating">8.9</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">8. Pulp Fiction (1994)</td>
#  <td class="movieRating">8.8</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">
#            9. The Lord of the Rings: The Fellowship of the Ring (2001)
#          </td>
#  <td class="movieRating">8.8</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">10. The Good, the Bad and the Ugly (1966)</td>
#  <td class="movieRating">8.8</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">11. Forrest Gump (1994)</td>
#  <td class="movieRating">8.8</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">
#            12. Spider-Man: Across the Spider-Verse (2023)
#          </td>
#  <td class="movieRating">8.8</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">13. Fight Club (1999)</td>
#  <td class="movieRating">8.7</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">
#            14. The Lord of the Rings: The Two Towers (2002)
#          </td>
#  <td class="movieRating">8.7</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">15. Inception (2010)</td>
#  <td class="movieRating">8.7</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">
#            16. Star Wars: Episode V - The Empire Strikes Back (1980)
#          </td>
#  <td class="movieRating">8.7</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">17. The Matrix (1999)</td>
#  <td class="movieRating">8.7</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">18. GoodFellas (1990)</td>
#  <td class="movieRating">8.7</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">19. One Flew Over the Cuckoo's Nest (1975)</td>
#  <td class="movieRating">8.6</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">20. Seven (1995)</td>
#  <td class="movieRating">8.6</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">21. It's a Wonderful Life (1946)</td>
#  <td class="movieRating">8.6</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">22. Seven Samurai (1954)</td>
#  <td class="movieRating">8.6</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">23. The Silence of the Lambs (1991)</td>
#  <td class="movieRating">8.6</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">24. Saving Private Ryan (1998)</td>
#  <td class="movieRating">8.6</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">25. City of God (2002)</td>
#  <td class="movieRating">8.6</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">26. Interstellar (2014)</td>
#  <td class="movieRating">8.6</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">27. Life Is Beautiful (1997)</td>
#  <td class="movieRating">8.6</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">28. The Green Mile (1999)</td>
#  <td class="movieRating">8.6</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">
#            29. Star Wars: Episode IV - A New Hope (1977)
#          </td>
#  <td class="movieRating">8.5</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">30. Terminator 2: Judgment Day (1991)</td>
#  <td class="movieRating">8.5</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">31. Back to the Future (1985)</td>
#  <td class="movieRating">8.5</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">32. Spirited Away (2001)</td>
#  <td class="movieRating">8.5</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">33. The Pianist (2002)</td>
#  <td class="movieRating">8.5</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">34. Psycho (1960)</td>
#  <td class="movieRating">8.5</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">35. Parasite (2019)</td>
#  <td class="movieRating">8.5</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">36. Leon (1994)</td>
#  <td class="movieRating">8.5</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">37. The Lion King (1994)</td>
#  <td class="movieRating">8.5</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">38. Gladiator (2000)</td>
#  <td class="movieRating">8.5</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">39. American History X (1998)</td>
#  <td class="movieRating">8.5</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">40. The Departed (2006)</td>
#  <td class="movieRating">8.5</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">41. Whiplash (2014)</td>
#  <td class="movieRating">8.5</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">42. The Prestige (2006)</td>
#  <td class="movieRating">8.5</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">43. The Usual Suspects (1995)</td>
#  <td class="movieRating">8.5</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">44. Casablanca (1942)</td>
#  <td class="movieRating">8.5</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">45. Grave of the Fireflies (1988)</td>
#  <td class="movieRating">8.5</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">46. Harakiri (1962)</td>
#  <td class="movieRating">8.5</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">47. Untouchable (2011)</td>
#  <td class="movieRating">8.5</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">48. Modern Times (1936)</td>
#  <td class="movieRating">8.4</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">49. Once Upon a Time in the West (1968)</td>
#  <td class="movieRating">8.4</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">50. Cinema Paradiso (1988)</td>
#  <td class="movieRating">8.4</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">51. Rear Window (1954)</td>
#  <td class="movieRating">8.4</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">52. Alien (1979)</td>
#  <td class="movieRating">8.4</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">53. City Lights (1931)</td>
#  <td class="movieRating">8.4</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">54. Apocalypse Now (1979)</td>
#  <td class="movieRating">8.4</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">55. Memento (2000)</td>
#  <td class="movieRating">8.4</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">56. Django Unchained (2012)</td>
#  <td class="movieRating">8.4</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">57. Raiders of the Lost Ark (1981)</td>
#  <td class="movieRating">8.4</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">58. WALL·E (2008)</td>
#  <td class="movieRating">8.4</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">59. The Lives of Others (2006)</td>
#  <td class="movieRating">8.4</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">60. Sunset Blvd. (1950)</td>
#  <td class="movieRating">8.4</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">61. Paths of Glory (1957)</td>
#  <td class="movieRating">8.4</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">62. Avengers: Infinity War (2018)</td>
#  <td class="movieRating">8.4</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">63. The Shining (1980)</td>
#  <td class="movieRating">8.4</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">64. The Great Dictator (1940)</td>
#  <td class="movieRating">8.4</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">65. Witness for the Prosecution (1957)</td>
#  <td class="movieRating">8.4</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">66. Spider-Man: Into the Spider-Verse (2018)</td>
#  <td class="movieRating">8.4</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">67. Aliens (1986)</td>
#  <td class="movieRating">8.3</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">68. American Beauty (1999)</td>
#  <td class="movieRating">8.3</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">69. The Dark Knight Rises (2012)</td>
#  <td class="movieRating">8.3</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">70. Galaxy's Echo (2023)</td>
#  <td class="movieRating">8.3</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">71. Unraveled Mystery (2023)</td>
#  <td class="movieRating">8.2</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">72. Oceans of Time (2023)</td>
#  <td class="movieRating">8.2</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">73. Last Breath (2023)</td>
#  <td class="movieRating">8.2</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">74. Dimensions Apart (2023)</td>
#  <td class="movieRating">8.2</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">75. Chasing Infinity (2023)</td>
#  <td class="movieRating">8.1</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">76. The Lost Kingdom (2023)</td>
#  <td class="movieRating">8.1</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">77. Golden Eclipse (2023)</td>
#  <td class="movieRating">8.1</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">78. Heart of The Ocean (2023)</td>
#  <td class="movieRating">8.1</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">79. Cursed Shadows (2023)</td>
#  <td class="movieRating">8.0</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">80. Memory of A Ghost (2023)</td>
#  <td class="movieRating">8.0</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">81. Mystic Sunrise (2023)</td>
#  <td class="movieRating">8.0</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">82. Whisper of the Wind (2023)</td>
#  <td class="movieRating">8.0</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">83. Frozen Heartbeat (2023)</td>
#  <td class="movieRating">7.9</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">84. The Last Horizon (2023)</td>
#  <td class="movieRating">7.9</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">85. City of Dreams (2023)</td>
#  <td class="movieRating">7.9</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">86. Veil of Destiny (2023)</td>
#  <td class="movieRating">7.9</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">87. Phoenix Rise (2023)</td>
#  <td class="movieRating">7.8</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">88. Secrets in The Sand (2023)</td>
#  <td class="movieRating">7.8</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">89. Riddle of The Sphinx (2023)</td>
#  <td class="movieRating">7.8</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">90. Solar Storm (2023)</td>
#  <td class="movieRating">7.8</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">91. Quantum Conundrum (2023)</td>
#  <td class="movieRating">7.7</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">92. Labyrinth of Illusions (2023)</td>
#  <td class="movieRating">7.7</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">93. Stars and Shadows (2023)</td>
#  <td class="movieRating">7.7</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">94. Eternal Flame (2023)</td>
#  <td class="movieRating">7.7</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">95. The Jade Serpent (2023)</td>
#  <td class="movieRating">7.6</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">96. Moon's Reflection (2023)</td>
#  <td class="movieRating">7.6</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">97. Dance of The Silver Phoenix (2023)</td>
#  <td class="movieRating">7.6</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">98. Crystal Visions (2023)</td>
#  <td class="movieRating">7.6</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">99. Silver Mirror (2023)</td>
#  <td class="movieRating">7.5</td>
#  </tr>,
#  <tr class="movieInfo">
#  <td class="movieTitle">100. The Forgotten Realm (2023)</td>
#  <td class="movieRating">7.5</td>
#  </tr>]

# %%
soup.select(".movieTitle") # all elements containing movie titles
# Out:
# [<td class="movieTitle">1. The Shawshank Redemption (1994)</td>,
#  <td class="movieTitle">2. The Godfather (1972)</td>,
#  <td class="movieTitle">3. The Dark Knight (2008)</td>,
#  <td class="movieTitle">4. The Godfather Part II (1974)</td>,
#  <td class="movieTitle">5. 12 Angry Men (1957)</td>,
#  <td class="movieTitle">6. Schindler's List (1993)</td>,
#  <td class="movieTitle">
#            7. The Lord of the Rings: The Return of the King (2003)
#          </td>,
#  <td class="movieTitle">8. Pulp Fiction (1994)</td>,
#  <td class="movieTitle">
#            9. The Lord of the Rings: The Fellowship of the Ring (2001)
#          </td>,
#  <td class="movieTitle">10. The Good, the Bad and the Ugly (1966)</td>,
#  <td class="movieTitle">11. Forrest Gump (1994)</td>,
#  <td class="movieTitle">
#            12. Spider-Man: Across the Spider-Verse (2023)
#          </td>,
#  <td class="movieTitle">13. Fight Club (1999)</td>,
#  <td class="movieTitle">
#            14. The Lord of the Rings: The Two Towers (2002)
#          </td>,
#  <td class="movieTitle">15. Inception (2010)</td>,
#  <td class="movieTitle">
#            16. Star Wars: Episode V - The Empire Strikes Back (1980)
#          </td>,
#  <td class="movieTitle">17. The Matrix (1999)</td>,
#  <td class="movieTitle">18. GoodFellas (1990)</td>,
#  <td class="movieTitle">19. One Flew Over the Cuckoo's Nest (1975)</td>,
#  <td class="movieTitle">20. Seven (1995)</td>,
#  <td class="movieTitle">21. It's a Wonderful Life (1946)</td>,
#  <td class="movieTitle">22. Seven Samurai (1954)</td>,
#  <td class="movieTitle">23. The Silence of the Lambs (1991)</td>,
#  <td class="movieTitle">24. Saving Private Ryan (1998)</td>,
#  <td class="movieTitle">25. City of God (2002)</td>,
#  <td class="movieTitle">26. Interstellar (2014)</td>,
#  <td class="movieTitle">27. Life Is Beautiful (1997)</td>,
#  <td class="movieTitle">28. The Green Mile (1999)</td>,
#  <td class="movieTitle">
#            29. Star Wars: Episode IV - A New Hope (1977)
#          </td>,
#  <td class="movieTitle">30. Terminator 2: Judgment Day (1991)</td>,
#  <td class="movieTitle">31. Back to the Future (1985)</td>,
#  <td class="movieTitle">32. Spirited Away (2001)</td>,
#  <td class="movieTitle">33. The Pianist (2002)</td>,
#  <td class="movieTitle">34. Psycho (1960)</td>,
#  <td class="movieTitle">35. Parasite (2019)</td>,
#  <td class="movieTitle">36. Leon (1994)</td>,
#  <td class="movieTitle">37. The Lion King (1994)</td>,
#  <td class="movieTitle">38. Gladiator (2000)</td>,
#  <td class="movieTitle">39. American History X (1998)</td>,
#  <td class="movieTitle">40. The Departed (2006)</td>,
#  <td class="movieTitle">41. Whiplash (2014)</td>,
#  <td class="movieTitle">42. The Prestige (2006)</td>,
#  <td class="movieTitle">43. The Usual Suspects (1995)</td>,
#  <td class="movieTitle">44. Casablanca (1942)</td>,
#  <td class="movieTitle">45. Grave of the Fireflies (1988)</td>,
#  <td class="movieTitle">46. Harakiri (1962)</td>,
#  <td class="movieTitle">47. Untouchable (2011)</td>,
#  <td class="movieTitle">48. Modern Times (1936)</td>,
#  <td class="movieTitle">49. Once Upon a Time in the West (1968)</td>,
#  <td class="movieTitle">50. Cinema Paradiso (1988)</td>,
#  <td class="movieTitle">51. Rear Window (1954)</td>,
#  <td class="movieTitle">52. Alien (1979)</td>,
#  <td class="movieTitle">53. City Lights (1931)</td>,
#  <td class="movieTitle">54. Apocalypse Now (1979)</td>,
#  <td class="movieTitle">55. Memento (2000)</td>,
#  <td class="movieTitle">56. Django Unchained (2012)</td>,
#  <td class="movieTitle">57. Raiders of the Lost Ark (1981)</td>,
#  <td class="movieTitle">58. WALL·E (2008)</td>,
#  <td class="movieTitle">59. The Lives of Others (2006)</td>,
#  <td class="movieTitle">60. Sunset Blvd. (1950)</td>,
#  <td class="movieTitle">61. Paths of Glory (1957)</td>,
#  <td class="movieTitle">62. Avengers: Infinity War (2018)</td>,
#  <td class="movieTitle">63. The Shining (1980)</td>,
#  <td class="movieTitle">64. The Great Dictator (1940)</td>,
#  <td class="movieTitle">65. Witness for the Prosecution (1957)</td>,
#  <td class="movieTitle">66. Spider-Man: Into the Spider-Verse (2018)</td>,
#  <td class="movieTitle">67. Aliens (1986)</td>,
#  <td class="movieTitle">68. American Beauty (1999)</td>,
#  <td class="movieTitle">69. The Dark Knight Rises (2012)</td>,
#  <td class="movieTitle">70. Galaxy's Echo (2023)</td>,
#  <td class="movieTitle">71. Unraveled Mystery (2023)</td>,
#  <td class="movieTitle">72. Oceans of Time (2023)</td>,
#  <td class="movieTitle">73. Last Breath (2023)</td>,
#  <td class="movieTitle">74. Dimensions Apart (2023)</td>,
#  <td class="movieTitle">75. Chasing Infinity (2023)</td>,
#  <td class="movieTitle">76. The Lost Kingdom (2023)</td>,
#  <td class="movieTitle">77. Golden Eclipse (2023)</td>,
#  <td class="movieTitle">78. Heart of The Ocean (2023)</td>,
#  <td class="movieTitle">79. Cursed Shadows (2023)</td>,
#  <td class="movieTitle">80. Memory of A Ghost (2023)</td>,
#  <td class="movieTitle">81. Mystic Sunrise (2023)</td>,
#  <td class="movieTitle">82. Whisper of the Wind (2023)</td>,
#  <td class="movieTitle">83. Frozen Heartbeat (2023)</td>,
#  <td class="movieTitle">84. The Last Horizon (2023)</td>,
#  <td class="movieTitle">85. City of Dreams (2023)</td>,
#  <td class="movieTitle">86. Veil of Destiny (2023)</td>,
#  <td class="movieTitle">87. Phoenix Rise (2023)</td>,
#  <td class="movieTitle">88. Secrets in The Sand (2023)</td>,
#  <td class="movieTitle">89. Riddle of The Sphinx (2023)</td>,
#  <td class="movieTitle">90. Solar Storm (2023)</td>,
#  <td class="movieTitle">91. Quantum Conundrum (2023)</td>,
#  <td class="movieTitle">92. Labyrinth of Illusions (2023)</td>,
#  <td class="movieTitle">93. Stars and Shadows (2023)</td>,
#  <td class="movieTitle">94. Eternal Flame (2023)</td>,
#  <td class="movieTitle">95. The Jade Serpent (2023)</td>,
#  <td class="movieTitle">96. Moon's Reflection (2023)</td>,
#  <td class="movieTitle">97. Dance of The Silver Phoenix (2023)</td>,
#  <td class="movieTitle">98. Crystal Visions (2023)</td>,
#  <td class="movieTitle">99. Silver Mirror (2023)</td>,
#  <td class="movieTitle">100. The Forgotten Realm (2023)</td>]

# %%
# we can use .get_text() to extract the content of the tags we selected
# we'll need to do it to each tag with a for loop: here we do it to the first one
soup.select(".movieTitle")[0].get_text()
# Out:
# '1. The Shawshank Redemption (1994)'

# %%
# the rating are inside a 'td' tag
soup.select("td.movieRating")[0].get_text()
# Out:
# '9.2'

# %% [markdown]
# ### Storing information in lists

# %%
#initialize empty lists
title = []
rating = []

# %%
# define the number of iterations of our for loop
# by checking how many elements are in the retrieved result set
# (this is equivalent but more robust than just explicitly defining 250 iterations)
num_iter = len(soup.select(".movieTitle"))
num_iter
# Out:
# 100

# %%
# iterate through the result set and retrive all the data
for i in range(num_iter):
    title.append(soup.select(".movieTitle")[i].get_text())
    rating.append(soup.select("td.movieRating")[i].get_text())

# %%
title
# Out:
# ['1. The Shawshank Redemption (1994)',
#  '2. The Godfather (1972)',
#  '3. The Dark Knight (2008)',
#  '4. The Godfather Part II (1974)',
#  '5. 12 Angry Men (1957)',
#  "6. Schindler's List (1993)",
#  '\n          7. The Lord of the Rings: The Return of the King (2003)\n        ',
#  '8. Pulp Fiction (1994)',
#  '\n          9. The Lord of the Rings: The Fellowship of the Ring (2001)\n        ',
#  '10. The Good, the Bad and the Ugly (1966)',
#  '11. Forrest Gump (1994)',
#  '\n          12. Spider-Man: Across the Spider-Verse (2023)\n        ',
#  '13. Fight Club (1999)',
#  '\n          14. The Lord of the Rings: The Two Towers (2002)\n        ',
#  '15. Inception (2010)',
#  '\n          16. Star Wars: Episode V - The Empire Strikes Back (1980)\n        ',
#  '17. The Matrix (1999)',
#  '18. GoodFellas (1990)',
#  "19. One Flew Over the Cuckoo's Nest (1975)",
#  '20. Seven (1995)',
#  "21. It's a Wonderful Life (1946)",
#  '22. Seven Samurai (1954)',
#  '23. The Silence of the Lambs (1991)',
#  '24. Saving Private Ryan (1998)',
#  '25. City of God (2002)',
#  '26. Interstellar (2014)',
#  '27. Life Is Beautiful (1997)',
#  '28. The Green Mile (1999)',
#  '\n          29. Star Wars: Episode IV - A New Hope (1977)\n        ',
#  '30. Terminator 2: Judgment Day (1991)',
#  '31. Back to the Future (1985)',
#  '32. Spirited Away (2001)',
#  '33. The Pianist (2002)',
#  '34. Psycho (1960)',
#  '35. Parasite (2019)',
#  '36. Leon (1994)',
#  '37. The Lion King (1994)',
#  '38. Gladiator (2000)',
#  '39. American History X (1998)',
#  '40. The Departed (2006)',
#  '41. Whiplash (2014)',
#  '42. The Prestige (2006)',
#  '43. The Usual Suspects (1995)',
#  '44. Casablanca (1942)',
#  '45. Grave of the Fireflies (1988)',
#  '46. Harakiri (1962)',
#  '47. Untouchable (2011)',
#  '48. Modern Times (1936)',
#  '49. Once Upon a Time in the West (1968)',
#  '50. Cinema Paradiso (1988)',
#  '51. Rear Window (1954)',
#  '52. Alien (1979)',
#  '53. City Lights (1931)',
#  '54. Apocalypse Now (1979)',
#  '55. Memento (2000)',
#  '56. Django Unchained (2012)',
#  '57. Raiders of the Lost Ark (1981)',
#  '58. WALL·E (2008)',
#  '59. The Lives of Others (2006)',
#  '60. Sunset Blvd. (1950)',
#  '61. Paths of Glory (1957)',
#  '62. Avengers: Infinity War (2018)',
#  '63. The Shining (1980)',
#  '64. The Great Dictator (1940)',
#  '65. Witness for the Prosecution (1957)',
#  '66. Spider-Man: Into the Spider-Verse (2018)',
#  '67. Aliens (1986)',
#  '68. American Beauty (1999)',
#  '69. The Dark Knight Rises (2012)',
#  "70. Galaxy's Echo (2023)",
#  '71. Unraveled Mystery (2023)',
#  '72. Oceans of Time (2023)',
#  '73. Last Breath (2023)',
#  '74. Dimensions Apart (2023)',
#  '75. Chasing Infinity (2023)',
#  '76. The Lost Kingdom (2023)',
#  '77. Golden Eclipse (2023)',
#  '78. Heart of The Ocean (2023)',
#  '79. Cursed Shadows (2023)',
#  '80. Memory of A Ghost (2023)',
#  '81. Mystic Sunrise (2023)',
#  '82. Whisper of the Wind (2023)',
#  '83. Frozen Heartbeat (2023)',
#  '84. The Last Horizon (2023)',
#  '85. City of Dreams (2023)',
#  '86. Veil of Destiny (2023)',
#  '87. Phoenix Rise (2023)',
#  '88. Secrets in The Sand (2023)',
#  '89. Riddle of The Sphinx (2023)',
#  '90. Solar Storm (2023)',
#  '91. Quantum Conundrum (2023)',
#  '92. Labyrinth of Illusions (2023)',
#  '93. Stars and Shadows (2023)',
#  '94. Eternal Flame (2023)',
#  '95. The Jade Serpent (2023)',
#  "96. Moon's Reflection (2023)",
#  '97. Dance of The Silver Phoenix (2023)',
#  '98. Crystal Visions (2023)',
#  '99. Silver Mirror (2023)',
#  '100. The Forgotten Realm (2023)']

# %%
rating
# Out:
# ['9.2',
#  '9.2',
#  '9.0',
#  '9.0',
#  '9.0',
#  '8.9',
#  '8.9',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.2',
#  '8.2',
#  '8.2',
#  '8.2',
#  '8.1',
#  '8.1',
#  '8.1',
#  '8.1',
#  '8.0',
#  '8.0',
#  '8.0',
#  '8.0',
#  '7.9',
#  '7.9',
#  '7.9',
#  '7.9',
#  '7.8',
#  '7.8',
#  '7.8',
#  '7.8',
#  '7.7',
#  '7.7',
#  '7.7',
#  '7.7',
#  '7.6',
#  '7.6',
#  '7.6',
#  '7.6',
#  '7.5',
#  '7.5']

# %% [markdown]
# ### Storing information in pandas DataFrames
#
# If you get an error try this:
# assert len(title) == len(rating)

# %%
import pandas as pd

# %%
movies_df = pd.DataFrame(
    {"movie_name": title,
     "rating": rating,
    }
)

# %%
movies_df.head()
# Out:
#                            movie_name rating
# 0  1. The Shawshank Redemption (1994)    9.2
# 1             2. The Godfather (1972)    9.2
# 2           3. The Dark Knight (2008)    9.0
# 3     4. The Godfather Part II (1974)    9.0
# 4              5. 12 Angry Men (1957)    9.0

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   movie_name  100 non-null    object
#  1   rating      100 non-null    object
# dtypes: object(2)
# memory usage: 1.7+ KB

# %% [markdown]
# #### Challenge: Cleaning the data
#
# An inherent part of web scraping is data cleaning. We managed to get the information we needed, but for it to be useful, we still need some extra steps:
#
# - Take the rank and the year out of the title and clean unnecessary spaces.
#
# - Tranform the data columns to the right types.

# %%
# your code here

# %%
# 1. Take the rank out of the title and clean unnecessary spaces

movies_df = movies_df.assign(
    Rank = movies_df['movie_name'].str.extract('(\d+)\.', expand=False),
    Movie = movies_df['movie_name'].str.extract('\.\s+(.*)\s+\(', expand=False),
    Year = movies_df['movie_name'].str.extract('\((\d+)\)', expand=False)
    ).drop(columns=['movie_name'])
movies_df
# Out:
#    rating Rank                        Movie  Year
# 0     9.2    1     The Shawshank Redemption  1994
# 1     9.2    2                The Godfather  1972
# 2     9.0    3              The Dark Knight  2008
# 3     9.0    4        The Godfather Part II  1974
# 4     9.0    5                 12 Angry Men  1957
# ..    ...  ...                          ...   ...
# 95    7.6   96            Moon's Reflection  2023
# 96    7.6   97  Dance of The Silver Phoenix  2023
# 97    7.6   98              Crystal Visions  2023
# 98    7.5   99                Silver Mirror  2023
# 99    7.5  100          The Forgotten Realm  2023
#
# [100 rows x 4 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_5871564707215608903 = autoviz.get_registered_df('df_5871564707215608903')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_5871564707215608903, *['index'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_8358185303232189420 = autoviz.get_registered_df('df_8358185303232189420')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_8358185303232189420, *['index'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_6753090462716512106 = autoviz.get_registered_df('df_6753090462716512106')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_6753090462716512106, *['Year', 'count()', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_8979145414019400675 = autoviz.get_registered_df('df_8979145414019400675')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_8979145414019400675, *['index', 'count()', None], **{})
# chart

# %%
# 2. Tranform the data columns to the right types.
movies_df.assign(
    rating = movies_df['rating'].astype(float),
    Rank = movies_df['Rank'].astype(int),
    Year = movies_df['Year'].astype(int)
)
# Out:
#     rating  Rank                        Movie  Year
# 0      9.2     1     The Shawshank Redemption  1994
# 1      9.2     2                The Godfather  1972
# 2      9.0     3              The Dark Knight  2008
# 3      9.0     4        The Godfather Part II  1974
# 4      9.0     5                 12 Angry Men  1957
# ..     ...   ...                          ...   ...
# 95     7.6    96            Moon's Reflection  2023
# 96     7.6    97  Dance of The Silver Phoenix  2023
# 97     7.6    98              Crystal Visions  2023
# 98     7.5    99                Silver Mirror  2023
# 99     7.5   100          The Forgotten Realm  2023
#
# [100 rows x 4 columns]
